# %% [markdown]
# <a href="https://colab.research.google.com/github/eiderrocha96-stack/Notebook_Agro_2026_1/blob/main/Rendimiento_Pulpa_Frutas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Rendimiento de Pulpa en Frutas
#
# **Contexo:**
#
#  Una planta procesadora necesita saber el **porcentaje de aprovechamiento**(R). El usuario debe ingresar el peso total de la fruta comprada y el peso de los residuos (cáscaras y semillas).
#
#  **Requerimiento:**
#
# 1. Solicitar el nombre de la planta.
# 2. Solicitar el peso total de la fruta comprada en Kg(P_total).
# 3. Solicitar el peso de los residuos en Kg(P_resid)
# 4.  calcular el porcentaje de aprovechamiento sasbiendo que:
#
# $$ Pulpa = P.total − P.resid$$
#
# $$ R=(Pulpa/Peso Total)×100 $$
#
# **Prueba del programa:**
#
#  Si se ingresa un peso total de **500kg** de fruta comprada y un peso de  residuos de **150kg**, el programa debee informar como salida  350kg de pulpa osea un rendimiento del **70%.**

# %%
#ENTRADA: Solicitar el nombre de la planta.
#Solicitar el peso total de la fruta comprada en Kg(P_total).
#Solicitar el peso de los residuos en Kg(P_resid)

nombre = input("Ingrese el nombre de la planta: ")
P_total = float(input("Ingrese el peso total de la fruta comprada en Kg: "))
P_resid = float(input("Ingrese el peso de los residuos en Kg: "))

#PROCESO: calcular el peso de la pulpa(p_pul) y rendimiento R)
p_pul =(P_total - P_resid)
R = (p_pul/P_total)*100

#SALIDA: informar el rendimiento de aprovechamiento
print("La planta", nombre, "tiene un rendimiento del", R, "%","(", p_pul,"Kg)" )
# Out:
# Ingrese el nombre de la planta: Rocha
# Ingrese el peso total de la fruta comprada en Kg: 500
# Ingrese el peso de los residuos en Kg: 150
# La planta Rocha tiene un rendimiento del 70.0 % ( 350.0 Kg)

# %% [markdown]
# ```markdown
# ### Explicación línea a línea del código de Rendimiento de Pulpa en Frutas
#
# Este código calcula el porcentaje de aprovechamiento de la fruta en una planta procesadora, basándose en el peso total de la fruta comprada y el peso de los residuos.
#
# ```python
# # ENTRADA: Solicitar el nombre de la planta.
# # Solicitar el peso total de la fruta comprada en Kg(P_total).
# # Solicitar el peso de los residuos en Kg(P_resid)
# ```
# Estas líneas son comentarios que describen el propósito de las siguientes tres líneas de código, que corresponden a la sección de entrada de datos.
#
# ```python
# nombre = input("Ingrese el nombre de la planta: ")
# ```
# Esta línea solicita al usuario que ingrese el nombre de la planta y almacena la entrada como una cadena de texto en la variable `nombre`.
#
# ```python
# P_total = float(input("Ingrese el peso total de la fruta comprada en Kg: "))
# ```
# Esta línea solicita al usuario que ingrese el peso total de la fruta comprada en kilogramos. La función `input()` lee la entrada como una cadena, y `float()` la convierte a un número decimal (punto flotante) para permitir cálculos, almacenándolo en la variable `P_total`.
#
# ```python
# P_resid = float(input("Ingrese el peso de los residuos en Kg: "))
# ```
# Similar a la línea anterior, esta línea solicita el peso de los residuos en kilogramos y lo convierte a un número decimal, almacenándolo en la variable `P_resid`.
#
# ```python
# # PROCESO: calcular el peso de la pulpa(p_pul) y rendimiento R)
# ```
# Este es un comentario que indica que las siguientes líneas realizarán los cálculos necesarios.
#
# ```python
# p_pul = (P_total - P_resid)
# ```
# Esta línea calcula el peso de la pulpa (`p_pul`) restando el peso de los residuos (`P_resid`) del peso total de la fruta (`P_total`).
#
# ```python
# R = (p_pul / P_total) * 100
# ```
# Esta línea calcula el porcentaje de rendimiento (`R`). Divide el peso de la pulpa (`p_pul`) por el peso total de la fruta (`P_total`) y luego multiplica el resultado por 100 para obtener un porcentaje.
#
# ```python
# # SALIDA: informar el rendimiento de aprovechamiento
# ```
# Este es un comentario que indica que la siguiente línea mostrará los resultados al usuario.
#
# ```python
# print("La planta", nombre, "tiene un rendimiento del", R, "%", "(", p_pul, "Kg)")
# ```
# Esta línea imprime el resultado final. Muestra un mensaje amigable que incluye el nombre de la planta, el porcentaje de rendimiento calculado (`R`), y el peso de la pulpa (`p_pul`).
# ```
