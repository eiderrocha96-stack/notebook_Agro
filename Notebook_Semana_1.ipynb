# %% [markdown]
# <a href="https://colab.research.google.com/github/eiderrocha96-stack/Notebook_Agro_2026_1/blob/main/Notebook_Semana_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ENTRAD: Entra ancho y alto de la madera en metros
ancho = input("Ingrese el ancho de la ventana en metros: ")
ancho = float(ancho)
alto = input("Ingrese el alto de la ventana en metros: ")
alto = float(alto)

# PROCESO: Calcula longitud de la madera (lm) en pies
# y el Área del vidrio en metros cuadrado
lm = 2 * (ancho + alto) * 3.25
av = 2 * (ancho * alto)

# SALIDA: Sale la longitud de la madera en pies
# el área del vidrio en metros cuadrados
print("Longitud de la madera es", lm, "pies de longitud")
print("El area del vidrio es", av, "metros cuadrados")
# Out:
# Ingrese el ancho de la ventana en metros: 1
# Ingrese el alto de la ventana en metros: 2
# Longitud de la madera es 19.5 pies de longitud
# El area del vidrio es 4.0 metros cuadrados
